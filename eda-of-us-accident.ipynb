# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/us-accidents/US_Accidents_Dec20.csv

# %%
#data Path
scr= '../input/us-accidents/US_Accidents_Dec20.csv'
data0= pd.read_csv(scr)
d=data0

# %%
data0.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
# ...

# %%
d
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 0              A-1  MapQuest  201.0         3  2016-02-08 05:46:00
# 1              A-2  MapQuest  201.0         2  2016-02-08 06:07:59
# 2              A-3  MapQuest  201.0         2  2016-02-08 06:49:27
# 3              A-4  MapQuest  201.0         3  2016-02-08 07:23:34
# 4              A-5  MapQuest  201.0         2  2016-02-08 07:39:07
# ...            ...       ...    ...       ...                  ...
# 4232536  A-4239402      Bing    NaN         2  2019-08-23 18:03:25
# 4232537  A-4239403      Bing    NaN         2  2019-08-23 19:11:30
# 4232538  A-4239404      Bing    NaN         2  2019-08-23 19:00:21
# 4232539  A-4239405      Bing    NaN         2  2019-08-23 19:00:21
# 4232540  A-4239406      Bing    NaN         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  ...  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN  ...
# ...

# %%
# if u don't know about data, assuming u simply got csv from friend or manager
# in that case
#1st think want to know what column it contains, what does it contain what does it represent etc
# if it is large file like this one we can't read it in excel with 
# we need something like panda and all to read file and all

# %%
#displays columns name
d.columns
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
# to check no of coulmns

# %%
# No of columns
len(d.columns)
# Out:
# 49

# %%
#no of rows
len(d)
# Out:
# 4232541

# %%
# but easier way is to check all this is to do 
# it will show u columns name along with no of rows
# variable types (i.e dtype) ,memory usage 
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4232541 entries, 0 to 4232540
# Data columns (total 49 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   TMC                    float64
#  3   Severity               int64
#  4   Start_Time             object
#  5   End_Time               object
#  6   Start_Lat              float64
#  7   Start_Lng              float64
#  8   End_Lat                float64
#  9   End_Lng                float64
#  10  Distance(mi)           float64
#  11  Description            object
#  12  Number                 float64
#  13  Street                 object
#  14  Side                   object
#  15  City                   object
#  16  County                 object
#  17  State                  object
#  18  Zipcode                object
#  19  Country                object
#  20  Timezone               object
# ...

# %% [markdown]
# Took 1:06.74 to compute till above line

# %%
#Pandas data frame numerical column statistics
# will give count, mean , std, min , 25% , 50%, 75% , max

d.describe()
# Out:
#                 TMC      Severity     Start_Lat     Start_Lng       End_Lat  \
# count  2.716477e+06  4.232541e+06  4.232541e+06  4.232541e+06  1.516064e+06
# mean   2.083517e+02  2.305035e+00  3.639782e+01 -9.546420e+01  3.690061e+01
# std    2.124413e+01  5.332261e-01  4.964404e+00  1.735319e+01  5.165629e+00
# min    2.000000e+02  1.000000e+00  2.455527e+01 -1.246238e+02  2.457011e+01
# 25%    2.010000e+02  2.000000e+00  3.352058e+01 -1.173570e+02  3.385420e+01
# 50%    2.010000e+02  2.000000e+00  3.582542e+01 -9.002078e+01  3.735134e+01
# 75%    2.010000e+02  3.000000e+00  4.018313e+01 -8.084682e+01  4.072593e+01
# max    4.060000e+02  4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01
#
#             End_Lng  Distance(mi)        Number  Temperature(F)  \
# count  1.516064e+06  4.232541e+06  1.544592e+06    4.142641e+06
# mean  -9.859901e+01  3.357021e-01  6.141507e+03    6.147799e+01
# std    1.849590e+01  1.602143e+00  1.492268e+04    1.852586e+01
# ...

# %% [markdown]
# # Termelogy Explaination
#
# Count : no of elements/ Entry
# mean :
# std:
# min:
# 25%
# 50%
# 75%
# max:

# %% [markdown]
# **Questions after seeing data**
#
# 1. Are there more accident in warmer or colder area and effect of humidity on no of accidents.
# 2. Which states have the highest no of accidents. Arrange as per states. Also accident per Capita.

# %%
numerics= ['int16','int32' , 'int64', 'float16','float32','float64']
numeric_d=d.select_dtypes(include= numerics)
len(numeric_d.columns)
# Out:
# 15

# %% [markdown]
# So there are total 15 columns with numerical value
#
# *till here it took 1:01.47 ran after previous time and after kenel restart*

# %%
# now check for missing values

# isnull() & notnull() : both function help in checking weather a value is NaN or not. 
# These function can also be used in pandasSeries in order to find null values in series.
# isna() is same as isnull()


#dropna()
# fillna()
# replace()
# interpolate()

"""Lets check for total no of missing values
Note that isnull returns boolen so to get the sum we use .sum() function
which will return missing values per column
than we might want to know percentage of missing values per columns """
d.isna().sum()
# Out:
# ID                             0
# Source                         0
# TMC                      1516064
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  2716477
# End_Lng                  2716477
# Distance(mi)                   0
# Description                    2
# Number                   2687949
# Street                         0
# Side                           0
# City                         137
# County                         0
# State                          0
# Zipcode                     1292
# Country                        0
# Timezone                    4615
# Airport_Code                8973
# Weather_Timestamp          62644
# Temperature(F)             89900
# Wind_Chill(F)            1896001
# Humidity(%)                95467
# Pressure(in)               76384
# Visibility(mi)             98668
# ...

# %%
# Sorting data in ascending order
# .sort_values() arrange on decending order
d.isna().sum().sort_values(ascending=False)
# Out:
# End_Lng                  2716477
# End_Lat                  2716477
# Number                   2687949
# Precipitation(in)        2065589
# Wind_Chill(F)            1896001
# TMC                      1516064
# Wind_Speed(mph)           479326
# Visibility(mi)             98668
# Weather_Condition          98383
# Humidity(%)                95467
# Temperature(F)             89900
# Wind_Direction             83611
# Pressure(in)               76384
# Weather_Timestamp          62644
# Airport_Code                8973
# Timezone                    4615
# Zipcode                     1292
# Sunrise_Sunset               141
# Civil_Twilight               141
# Nautical_Twilight            141
# Astronomical_Twilight        141
# City                         137
# Description                    2
# Country                        0
# Junction                       0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# ...

# %%
# lets calculate percentage wise
missing_percentage = d.isna().sum().sort_values(ascending= False)/ len(d)
missing_percentage
# Out:
# End_Lng                  6.418076e-01
# End_Lat                  6.418076e-01
# Number                   6.350674e-01
# Precipitation(in)        4.880258e-01
# Wind_Chill(F)            4.479581e-01
# TMC                      3.581924e-01
# Wind_Speed(mph)          1.132478e-01
# Visibility(mi)           2.331176e-02
# Weather_Condition        2.324443e-02
# Humidity(%)              2.255548e-02
# Temperature(F)           2.124020e-02
# Wind_Direction           1.975433e-02
# Pressure(in)             1.804684e-02
# Weather_Timestamp        1.480057e-02
# Airport_Code             2.120003e-03
# Timezone                 1.090362e-03
# Zipcode                  3.052540e-04
# Sunrise_Sunset           3.331332e-05
# Civil_Twilight           3.331332e-05
# Nautical_Twilight        3.331332e-05
# Astronomical_Twilight    3.331332e-05
# City                     3.236826e-05
# Description              4.725294e-07
# Country                  0.000000e+00
# Junction                 0.000000e+00
# ...

# %%
# this is not a dataframe this is a series 
# because here we have only one column of data

# but 1st filter all zero values 

# missing_percentage != 0 // since this will return  booleen we should store it's index values
missing_percentage[missing_percentage != 0]
# it only keep rows where we have value true
# Out:
# End_Lng                  6.418076e-01
# End_Lat                  6.418076e-01
# Number                   6.350674e-01
# Precipitation(in)        4.880258e-01
# Wind_Chill(F)            4.479581e-01
# TMC                      3.581924e-01
# Wind_Speed(mph)          1.132478e-01
# Visibility(mi)           2.331176e-02
# Weather_Condition        2.324443e-02
# Humidity(%)              2.255548e-02
# Temperature(F)           2.124020e-02
# Wind_Direction           1.975433e-02
# Pressure(in)             1.804684e-02
# Weather_Timestamp        1.480057e-02
# Airport_Code             2.120003e-03
# Timezone                 1.090362e-03
# Zipcode                  3.052540e-04
# Sunrise_Sunset           3.331332e-05
# Civil_Twilight           3.331332e-05
# Nautical_Twilight        3.331332e-05
# Astronomical_Twilight    3.331332e-05
# City                     3.236826e-05
# Description              4.725294e-07
# dtype: float64

# %%
missing_percentage[missing_percentage != 0].plot(kind= 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **if any columns has more than half missing value than that column may not be of any use**
#
# So we can skip them from data
#
# Either drop it or never use it
#
# but dropping is more effective as it save space and time

# %%
d.columns
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# #Source 48:00 https://www.youtube.com/watch?v=kLDTbavcmd0

# %% [markdown]
# ## Columns to analyze :
#
# 1. City
# 2. Start time
# 3. Start Lat , Start Lng
# 4. Temperature
# 5. Weather condition

# %% [markdown]
# #  City

# %%
# City
# this will display u city coulmn = d.City
# If we want to check if it is unique or not = d.City.unique()

print("No of unique cities =",+ len(d.City.unique()))  #to return no of unique cities
cities=d.City.unique()
print('Total no entries in cities column =', + len(d.City))
print(d.City.unique()[:100]) # to check 100 unique cities

# total no of cities in USA is unknow to me
# Out:
# No of unique cities = 12251
# Total no entries in cities column = 4232541
# ['Dayton' 'Reynoldsburg' 'Williamsburg' 'Westerville' 'Columbus'
#  'Miamisburg' 'Johnstown' 'Dublin' 'Canal Winchester' 'Lebanon' 'Sabina'
#  'Goshen' 'Waynesville' 'Springboro' 'Carroll' 'Oregonia' 'Independence'
#  'Maple Heights' 'Grove City' 'Findlay' 'Fairborn' 'Piqua' 'New Richmond'
#  'Batavia' 'Galena' 'Barberton' 'Akron' 'Mansfield' 'Cleveland' 'Bethel'
#  'Pataskala' 'Seville' 'Bellville' 'Troy' 'Wilmington' 'North Olmsted'
#  'Groveport' 'Orient' 'Tiro' 'Strongsville' 'Beavercreek' 'Circleville'
#  'Peebles' 'Hurricane' 'Xenia' 'Elyria' 'Pickerington' 'Burbank'
#  'Zanesville' 'North Baltimore' 'Mount Sterling' 'Tipp City' 'Moraine'
#  'Hilliard' 'Bowling Green' 'Maineville' 'Vermilion' 'Milford' 'Brookpark'
#  'Fraziers Bottom' 'Cambridge' 'Delaware' 'Moscow' 'Oberlin' 'Sardinia'
#  'Lewis Center' 'Urbancrest' 'Brecksville' 'Frankfort' 'Blanchester'
# ...

# %%
# Cities by accident
cities_by_accident = d.City.value_counts()
print(cities_by_accident)
# Out:
# Houston          114905
# Los Angeles       92701
# Charlotte         88887
# Dallas            77303
# Austin            70538
#                   ...
# Wallis                1
# South Solon           1
# Twin Mountain         1
# Keshena               1
# Niagara               1
# Name: City, Length: 12250, dtype: int64

# %%
# top 20
cities_by_accident[:20]

# onething to observe the city with highest no of population doesn't show up in top 20 cities with accident ie New York
# Out:
# Houston          114905
# Los Angeles       92701
# Charlotte         88887
# Dallas            77303
# Austin            70538
# Miami             63162
# Raleigh           52876
# Atlanta           46328
# Baton Rouge       42814
# Nashville         41850
# Orlando           39561
# Oklahoma City     39484
# Sacramento        38061
# Phoenix           32805
# Minneapolis       31781
# San Diego         29416
# Seattle           28004
# Richmond          27907
# San Antonio       27516
# Jacksonville      24009
# Name: City, dtype: int64

# %%
type(cities_by_accident)
# will return = pandas.core.series.Series
# This is some list attached to some indexes 
# list(cities_by_accident) code to check list
# Out:
# pandas.core.series.Series

# %%
# Why in d.City keep returning False
print('New York' in d.City)
print('NY' in d.State)
# totla no of states in USA is 50 and if terretary included its 52
print('Houston' in d.City)

# why this is returning False
# though we see it has highest no of accidents
# Out:
# False
# False
# False

# %%
d.City.isin(['New York']).any()
# Out:
# True

# %%
# to check total no of entries from New York
d[d['City'] == 'New York']
# Out:
#                 ID         Source    TMC  Severity           Start_Time  \
# 194401    A-194408       MapQuest  201.0         2  2016-12-01 08:21:11
# 194415    A-194422       MapQuest  241.0         3  2016-12-01 08:49:35
# 194468    A-194475       MapQuest  245.0         2  2016-12-01 12:08:26
# 194533    A-194540       MapQuest  201.0         2  2016-12-02 05:19:11
# 194551    A-194558  MapQuest-Bing  241.0         2  2016-12-02 07:09:04
# ...            ...            ...    ...       ...                  ...
# 4230546  A-4237412           Bing    NaN         2  2019-08-20 14:54:26
# 4231092  A-4237958           Bing    NaN         2  2019-08-21 17:32:29
# 4231627  A-4238493           Bing    NaN         2  2019-08-22 08:16:10
# 4231647  A-4238513           Bing    NaN         2  2019-08-22 15:14:32
# 4232146  A-4239012           Bing    NaN         2  2019-08-23 10:04:09
#
#                     End_Time  Start_Lat  Start_Lng    End_Lat    End_Lng  ...  \
# ...

# %%
cities_by_accident[59:62]
# Out:
# New York      10255
# Birmingham     9986
# Memphis        9983
# Name: City, dtype: int64

# %%
# plotting fro top 60
cities_by_accident[:60].plot(kind= 'barh', figsize=(15,20), fontsize=18)

# in case of figsize 2nd parameter = distance between X axis and 1st parameter = distance between y

# we can also print multiple graph with differen range 0:20, 20:40 and 40:60
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.set_style('darkgrid') # darkgrid theme

# %%
sns.distplot(cities_by_accident)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %% [markdown]
# **From above graph we infer that most cities have less than 2000 accidents**

# %%
high_accident_cities = cities_by_accident[cities_by_accident >=1000]
low_accident_cities = cities_by_accident[cities_by_accident < 1000]

# %%
print(len(high_accident_cities))
# it returns 784 which is around 5% of 12k cities 
percent = len(high_accident_cities)/len(cities) #used cities as cities store unique city though cities entry are above 42k
print('Percentage =', percent )
# Out:
# 704
# Percentage = 0.05746469675944821

# %%
# Distplot for these 700 cities with accident above 10k

sns.distplot(high_accident_cities)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
#displot for low accident cities
sns.distplot(low_accident_cities)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %% [markdown]
# here we can observe that both high and low dist plot shows exponensial graph
# ### we can use logrithmic scale for our convenience

# %%
# how to set fig size in seaborn
sns.histplot(cities_by_accident,  log_scale= True)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Count'>

# %% [markdown]
# *Above graph shows that we have most data between 0 to 100*
#
# one intresting inference there are some 1200+ cities with <10 accidents most probably 0 or 1

# %%
cities_by_accident[cities_by_accident== 1]
# this shows some 1267 cities (i.e 10% of total cities) have only 1 accident

# check if there is issue with the data or
# Out:
# Montandon        1
# Maylene          1
# Wilkinson        1
# Elk Rapids       1
# Mc Comb          1
#                 ..
# Wallis           1
# South Solon      1
# Twin Mountain    1
# Keshena          1
# Niagara          1
# Name: City, Length: 1267, dtype: int64

# %% [markdown]
# ** Which states have the most accidents**

# %% [markdown]
# ## Start Time

# %%
d.Start_Time
# insights : data is arranged in asending order with 2nd feb 2016 and ends on 2019 with format YYYY-MM-DD
# data have date followed by time 
# dtype is object i.e sting
# So lets parse sting to date
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 4232536    2019-08-23 18:03:25
# 4232537    2019-08-23 19:11:30
# 4232538    2019-08-23 19:00:21
# 4232539    2019-08-23 19:00:21
# 4232540    2019-08-23 18:52:06
# Name: Start_Time, Length: 4232541, dtype: object

# %%
pd.to_datetime(d.Start_Time)
# now if u look at the last line of output u will se dtype = Datetime64
# Thus converted
# Out:
# 0         2016-02-08 05:46:00
# 1         2016-02-08 06:07:59
# 2         2016-02-08 06:49:27
# 3         2016-02-08 07:23:34
# 4         2016-02-08 07:39:07
#                   ...
# 4232536   2019-08-23 18:03:25
# 4232537   2019-08-23 19:11:30
# 4232538   2019-08-23 19:00:21
# 4232539   2019-08-23 19:00:21
# 4232540   2019-08-23 18:52:06
# Name: Start_Time, Length: 4232541, dtype: datetime64[ns]

# %%
# Lets overwrite this to original database
d.Start_Time = pd.to_datetime(d.Start_Time)
d.Start_Time
# check last line for confirmation
# Out:
# 0         2016-02-08 05:46:00
# 1         2016-02-08 06:07:59
# 2         2016-02-08 06:49:27
# 3         2016-02-08 07:23:34
# 4         2016-02-08 07:39:07
#                   ...
# 4232536   2019-08-23 18:03:25
# 4232537   2019-08-23 19:11:30
# 4232538   2019-08-23 19:00:21
# 4232539   2019-08-23 19:00:21
# 4232540   2019-08-23 18:52:06
# Name: Start_Time, Length: 4232541, dtype: datetime64[ns]

# %% [markdown]
# #### **Why we can't plot a graph with Start_Time Column?**
# *>> Because it is time stamp and have high chance of being unique as it store data upto second*

# %%
 # what is more imp analysing power not syntax
sns.distplot(d.Start_Time.dt.hour, bins=24, kde= False)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
# Show percentage as it will be more fruitful 
sns.distplot(d.Start_Time.dt.hour , bins= 24 , kde= False , norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# > Most accidents happen between 6-10 May be due to office and school rush
# and again between 3pm to 6pm
#
# It would be intresting if we overlap this graph with trafic data
# > We can so this by adding external data source by minutebyminute traffic details or may be hourByHour traffic analysis

# %%
sns.distplot(d.Start_Time.dt.dayofweek , bins= 7 , kde= False , norm_hist=True)
#bins = interval
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# > Insight on weeekends no of accidents are low

# %%
# is the distribution of accidents by hour the same on weekends as on weekdays
# This--> d.Start_Time.dt.dayofweek==6 returns boolean so now we will store this in index
sundays_st=d.Start_Time[d.Start_Time.dt.dayofweek==6] # Monday is 0 and Sunday is 6 rest all between 
len(sundays_st)
sns.distplot(sundays_st.dt.hour , bins= 24 , kde= False , norm_hist=True)

# basicall
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# Insights: On sundays peak occur between 10am and 3pm unlike weekdays
# here u can see we get a nice gussian curve aka bell curve on sunday but in case of week days we get 2 Gussian curves if we change our perception
# ![on%20sun.jpg](attachment:on%20sun.jpg)
#
# ![on%20weekdays.jpg](attachment:on%20weekdays.jpg)

# %%
sns.distplot(sundays_st.dt.month , bins= 12 , kde= False , norm_hist=True)
# view of sunday only
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
sns.distplot(d.Start_Time.dt.month , bins= 12 , kde= False , norm_hist=True) 
#view of all days of week
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# #### Can u explain the month wise trend of accidents?
# > How to do this drill down the data itself
# or do some research like why are there are more accidents in winter
#
# yeah there are some reaserch which shows relation between no of accidents related to weather and type of road. But since we don't have knowlegde about of type of road we can't conclude it by this data set alone we need to add data set of type of roads in USA.

# %%
# lets check for 2019
df_2019 = d[d.Start_Time.dt.year == 2019]
sns.distplot(df_2019.Start_Time.dt.month, bins=12, kde= False , norm_hist= True) # norm_hist= True gives percentage in graph
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# Since in 2016 jan month was missing which mean 1/4th of data was missing when considered for 4 years.
# Thus graph was a bit skewed.

# %%
# lets check for 2018
df_2018 = d[d.Start_Time.dt.year == 2018]
sns.distplot(df_2018.Start_Time.dt.month, bins=12, kde= False , norm_hist= True) # norm_hist= True gives percentage in graph
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
# lets check for 2016
df_2016 = d[d.Start_Time.dt.year == 2016]
sns.distplot(df_2016.Start_Time.dt.month, bins=12, kde= False , norm_hist= True) # norm_hist= True gives percentage in graph
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# Interpretation : Data is mising for 2016 atleast for 1st 7month with January 16 and July 16 tending to 0
# #### So we can conclude that we can't depend on graph of month for conclusion that accident depends on weather
# Though we can see that Winters in USA have high accident rate. weather may affect accident due to snow fall and all but graph and provided data set don't give us firm reason to believe so.

# %%
#checking for source of data
d.Source
# Out:
# 0          MapQuest
# 1          MapQuest
# 2          MapQuest
# 3          MapQuest
# 4          MapQuest
#              ...
# 4232536        Bing
# 4232537        Bing
# 4232538        Bing
# 4232539        Bing
# 4232540        Bing
# Name: Source, Length: 4232541, dtype: object

# %%
d.Source.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Source'>

# %% [markdown]
# As we can see there are 2 source.
# so now lets check both source for any bias or missing data.

# %%
# lets check for 2019 with Bing's Data 
df_2019 = d[d.Start_Time.dt.year == 2019]
df_2019_Bing= df_2019[df_2019.Source == 'Bing']
sns.distplot(df_2019_Bing.Start_Time.dt.month, bins=12, kde= False , norm_hist= True) # norm_hist= True gives percentage in graph
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
# lets check for 2019 with MapQuest's Data 
df_2019 = d[d.Start_Time.dt.year == 2019]
df_2019_MapQuest= df_2019[df_2019.Source == 'MapQuest']
sns.distplot(df_2019_MapQuest.Start_Time.dt.month, bins=12, kde= False , norm_hist= True) # norm_hist= True gives percentage in graph
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# Interpretation
#
# Bing data shows accident more prone in winter and may be baised
# where as MapQuest shows more balanced data presentation
#
#
# ### This raise another question if both were counting data simultaniously then both must have similar data trend.

# %% [markdown]
# Also seeing Bing data Size we can omit it as it constitute somewhere around 33% of data

# %% [markdown]
# ## Temperature

# %%
""" why does this give error
print("No of unique temperature entry =",+ len(d.Temperature(F).unique()))  #to return no of unique temperature
print('Total no of temperature entry =', + len(d.Temperature(F)))
"""
# Out:
# ' why does this give error\nprint("No of unique temperature entry =",+ len(d.Temperature(F).unique()))  #to return no of unique temperature\nprint(\'Total no of temperature entry =\', + len(d.Temperature(F)))\n'

# %% [markdown]
# ## Start Latitude & Longitude

# %%
d.Start_Lat
# Out:
# 0          39.865147
# 1          39.928059
# 2          39.063148
# 3          39.747753
# 4          39.627781
#              ...
# 4232536    34.002480
# 4232537    32.766960
# 4232538    33.775450
# 4232539    33.992460
# 4232540    34.133930
# Name: Start_Lat, Length: 4232541, dtype: float64

# %%
d.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 4232536   -117.379360
# 4232537   -117.148060
# 4232538   -117.847790
# 4232539   -118.403020
# 4232540   -117.230920
# Name: Start_Lng, Length: 4232541, dtype: float64

# %% [markdown]
# Latitude is Horizantal line
# Longitude us Verticle line
# Both latitude and longitude are measured in degrees, which are in turn divided into minutes and seconds.

# %%
sns.scatterplot(x=d.Start_Lng , y=d.Start_Lat)
# Out:
# <AxesSubplot:xlabel='Start_Lng', ylabel='Start_Lat'>

# %% [markdown]
# It is not accurate map of usa as we have simply plotted all points on graph not on Map

# %%
# Reduce the size of points
sns.scatterplot(x=d.Start_Lng , y=d.Start_Lat , size=0.001)
# Out:
# <AxesSubplot:xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
# doing this to increase computation speed
sample_df=d.sample(int(0.1*len(d)))

# %%
sns.scatterplot(x=sample_df.Start_Lng , y=sample_df.Start_Lat , size=0.001)
# Out:
# <AxesSubplot:xlabel='Start_Lng', ylabel='Start_Lat'>

# %% [markdown]
# I think sampling doesn't pick data randomly it take top 10%

# %% [markdown]
# ### Using folium library to plot points on map

# %%
import folium

# %%
folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
lat, lon = d.Start_Lat[0], d.Start_Lng[0]
lat, lon
# Out:
# (39.865147, -84.058723)

# %%
folium.Map
folium.Marker((lat,lon)) # takes tuple as input
# Map didn't showed because we need to return the map

# %%
map=folium.Map

marker=folium.Marker((lat,lon))

marker.add_to(map)

map

# %%
> **Lets try heatmap**

# %%
# create a list of lon and lat and then zip it
zip(list(d.Start_Lat), list(d.Start_Lng))

# %%
# now if we list it again it will give us list of pairs
list(zip(list(d.Start_Lat), list(d.Start_Lng)))
# Out:
# [(39.865147, -84.058723),
#  (39.928059, -82.831184),
#  (39.063148, -84.032608),
#  (39.747753, -84.205582),
#  (39.627781, -84.188354),
#  (40.10059, -82.925194),
#  (39.758274, -84.230507),
#  (39.770382, -84.194901),
#  (39.778061, -84.172005),
#  (40.10059, -82.925194),
#  (39.952812, -83.119293),
#  (39.932709, -82.83091),
#  (39.737633, -84.149933),
#  (39.79076, -84.241547),
#  (39.972038, -82.913521),
#  (39.745888, -84.17041),
#  (39.748329, -84.224007),
#  (39.752174, -84.239952),
#  (39.740669, -84.184135),
#  (39.790703, -84.244461),
#  (40.052509, -82.882332),
#  (39.773346, -84.224686),
#  (39.628288, -84.226151),
#  (40.023487, -82.994888),
#  (39.761379, -84.259216),
#  (40.158024, -82.641762),
#  (39.733219, -84.159653),
#  (39.775303, -84.200523),
#  (39.789322, -84.239105),
#  (39.75872, -84.183762),
#  (40.081459, -83.122398),
#  (39.83321, -84.112946),
#  (40.042725, -82.997307),
#  (39.974415, -82.848854),
#  (39.994766, -83.02449),
#  (40.006477, -83.030991),
# ...

# %%
from folium.plugins import HeatMap

# %%
map= folium.Map()

HeatMap(zip(list(d.Start_Lat), list(d.Start_Lng))).add_to(map)
map

# %% [markdown]
# ## Ask Questions
# * Are there more accidents in warmer or colder area?
# * Which 5 states have most no of accidents as per capita?
# * Does New York show upo in the data? If yes, why is the count lower if this the most populated city?
# * Among the top 100 cities in number of accidents, which states do they belong to most frequently
# * What time of the day are the accidents most frequent in?
#     Which days of the week have the most accidents
#     Which month have most accident (HEATMAP might work)
#     Trend of accident year wise Increasing or decreasing?
#
#  ## Add these data set to fine tune ur EDA
# 1. Type op roads in USA
# 2. Traffic per hour in USA from FEb 2016 to 2019 (check time stamp for more details
# 3.

# %% [markdown]
# # Summary and conclusion
#
# ## insights:
#
# 1. less than 5% of cities have more than 1000 yearly accidents.
# 2. Over 1200 cities have reported just 1 case though the data set have data worth 4 year (need to investigate)
# 3. The no of accidents decreases exponensially
# 4. Almost half data is missing from 2016. And month of Jan and July have almost nill value
# 5.  So we can conclude that we can't depend on graph of month for conclusion that accident depends on weather
#     Though we can see that Winters in USA have high accident rate. weather may affect accident due to snow fall and all
#       but graph and provided data set don't give us firm reason to believe so
# 6. Since there is inconsistency lets check for source of data.
#         Interpretation
#     Bing data shows accident more prone in winter and may be baised
#     where as MapQuest shows more balanced data presentation.
#     Bing Data may have some issue. This is prety commmon with real data.
#     even if we remove Bing data we will be left with 60% data which Still will be of great help.
#
# ### Asumption: data provided in data Set are correct.
